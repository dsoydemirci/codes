# %%
<br> satır boşluğu
lorem10 yaz mesela taba bas 10 kelimeli bişe yazar


 !  (ünlem) yazıp taba basınca bunlar gelir

<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>Document</title>
</head>
<body>
    
</body>
</html>

# %%
<meta name="" content="">

# %%
<meta name="keywords" content="hali,yikama">
<meta name="title" content="Halı Yıkama Fabrikası">
<meta name="description" content="7/24 halı yıkama 1994 ten beri">

# %%
<h1>  Lorem ipsum dolor sit amet.</h1> yazıyı kalınlaştırır
h2 h3 h4 diye gidersen yazı boyutu git gide düşer.
h1 den h2 h3 h4 e önem değeri düşer
h2 den en fazla 4 tane oluşturma tavsiye edilir
h1 den 1 tane olması iyidir
*****bodye eklenir****

# %%
*****bodye eklenir*******
<p>
       
    </p>
    araya yazı yazcan snra bi p etiketi daha yapıp onunda arasına yazı yazcan
    br koymana gerek kalmadan boşluk bırakmış olursun.
    ve böyle br yerine p ile yapma sebebimiz css te ayrı ayrı paragrafların
    rengini boyutunu ayrı ayarlayabilmek için.

# %%
<p>
       <b>lorem ipsum</b> dolor sit amet.
    </p>
    <b> arasındaki yazı koyulaştı.
    aynı şeyi <strong> da yapıyor. strong yazının önemi için kullanılır.
    
    
    
 <p>
       <i>askaltmaaa</i>slorem ipsum dolor sit amet.
    </p>
    <i> ise italik yazdırır.
    <em> de italik yazdırır.em yazının önemi için kullanılır.yani bu önemlidemek için.
    
    <u> yazının altını çizer.
    <ins> yazının altını çizer.
    <sup> yazıyı yukarı alır. bu x kareyi yazarken işe yarıyor 
    x<sup>2</sup> böyle yapınca
    bildiğin x kare yazısı gibi oluyor 2 yi üste alıyor.
    <sub> ise yazıyı aşşağı alır.
    <del> yazıyı çizer.
    <mark> sarıya boyar. ama kalın şeyle çizmiş gibi.
    <hr> çizgi çeker dümdüz. başlığı yaz sonra başlığın alt satırına bunu koy.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>Document</title>
</head>
<body>
    <ul>
        <li>
           <p>Lorem ipsum dolor.</p> 
           
           <ul>
               <li>  alt eleman
               
                <ul>
               <li>  alt eleman</li>
           </ul>
               </li>
           </ul>
        </li>
        <li>
            Lorem ipsum dolor.
        </li>
        <li>
            Lorem ipsum dolor.
        </li>
    </ul>
</body>
</html>
çıktı: *Lorem ipsum dolor.
         *alt eleman
               *alt eleman
        *Lorem ipsum dolor.
        *Lorem ipsum dolor.

# %%
 ol>li*2 yazdık aşağısı oldu.   
    
    <ol>
       <li></li>
       <li></li>
   </ol>

# %%
   <ol >
       <li>Lorem ipsum.</li>
       <li>Lorem ipsum</li>
       <li>Lorem ipsum</li>
       
   </ol>
ççıktı
1.Lorem ipsum.
2.Lorem ipsum
3.Lorem ipsum

# %%
 <ol start="5" >
       <li>Lorem ipsum.</li>
       <li>Lorem ipsum</li>
       <li>Lorem ipsum</li>
       
   </ol>
çıktı
5.Lorem ipsum.
6.Lorem ipsum
7.Lorem ipsum

# %%
<ol start="5" type="A" >
       <li>Lorem ipsum.</li>
       <li>Lorem ipsum</li>
       <li>Lorem ipsum</li>
   </ol>

çıktı: alfabenin 5.sinden başlar.
    E.Lorem ipsum
    F.Lorem ipsum
    G.Lorem ipsum

# %%
https://docs.emmet.io/cheat-sheet/   kısayollar

# %%
 ol>li>p*2
    <ol>
        <li>
            <p></p>
        </li>
    </ol>

# %%
 <img src="images.jpg"> html ile aynı dosya içinde olacak resim sen ""ye basınca
    isimler çıkıyor zaten
    
    <img src="asd.jpg"width="100"> genişlik yükseklik orantılı ayarladık
    <img src="img/sads.jpg"width="1000"> img/ yazma sebebimiz resmin img dosya içindeolması
    <img src="../img/sads.jpg"width="1000">  ../ koyma sebebi üst dizine çıkmak çünkü html dosyası
    başka yerde çok mantıklı değil bu 
     <img src="internetsitesindekiresimlinki"> sağ tıkla resme incele yap src sindeki linki bul

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>Document</title>
</head>
<body>
   <form action="/Home/Register">
       
       
       <p>
           
           Ad: <input type="text"name="ad"required placeholder="adınızı giriniz">
           
           
       </p>
       <p>
           
           Soyad: <input type "text"name="soyad"required placeholder="soyadınızı giriniz" >
           
           
       </p>
       
       <p>
           Eposta <input type="email"name="email" required>
       </p>
        
           
           Parola: <input type="password">

           
           
       
        <p>
           
           Beni hatırla: <input type="checkbox" name ="benih">
           
           
       </p>
       
         <p>
           
           Erkek: <input type="radio" name="cinsiyet">
           Kadın: <input type="radio" name="cinsiyet">
           
       </p>
       <p>
           Hobiler<br>
           Sinema <input type="checkbox"name="hobi">
           Spor <input type="checkbox"name="hobi">
            pc <input type="checkbox"name="hobi">
       </p>
       <p>
          Şehir Seç:
           <select name="sehirler">
               <option>Kocaeli</option>
               <option>Samsun</option>
               <option>Bursa</option>
               <option>Antalya</option>
           </select>
       </p>
       <input type ="submit" value="Kaydetbakim">
   </form>
    
</body>
</html>

TYPE PASSWORD PAROLAYI GÖRÜNMEZ YAPAR **** BÖYLE
REQUİRED YAZMA SEBEBİ YAZMAYINCA ONU HATA VERSİN
PLACEHOLDER DA O İNPUT KUTU BOŞLUĞU İÇİNE SİLİK YAZI YAZIYO.

ERKEK KADIN YERİNDE name="cinsiyet" yapılma sebebi sadece birini seçebilsin diye
kodu yaz bak.

# %%
https://www.w3schools.com/html/html_form_input_types.asp

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>tablolar</title>
</head>
<body>
    <table border="1" width="%60"> border tablo çiziyo
                                   width%60 tarayıcının genişliğine
            <thead>                       göre tabloyu ayarlıyor.   
        
           <tr>                     thead tbody sınıflandırma için.
               <th>kurs adı</th>
               <th>saaat</th>
               <th>ders adet</th>
               
           </tr>
           </thead>
           <tbody>
           <tr>
            <td>KOMPLE WEBGELİŞ</td>
            <td>45</td>
            <td>300</td>

           </tr>
           <!--table row-->
           
           <tr>
           
           <!--table data-->
            <td>CORE 2 MVC EGİTİM</td>
            <td>30</td>
            <td rowspan="2">200</td> burda rowspanın görevi
                                    200 sayısını alttaki satırada
                                     kaplattırıyor.

            
            
        </tr>
        <tr>
           
           <!--table data-->
            <td colspan="2">CORE 2 MVC EGİTİM</td>
            colspan şu işe yarıyor o satırdaki sütünlardan kaçını bu yazı
            kaplasın.biz 2 tane dedik 2 tane kapladı.

            
            
        </tr>
        
        
        </tbody>
    </table>
</body>
</html>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>linkler</title>
</head>
<body>
    <a id="imagess" href="tables.html" target="_blank">images</a> blank yazma sebebi
                                                     ayrı sekmede açması için
    
    <a href="https://youtube.com">youtube</a>
    
    <a href="html5/images.jpg">fr</a>
    
    <a href="Yeni%20klas%C3%B6r.rar">aaa</a>
    
    <a href="header.html"><img src="img/indir.jpg"> </a>
    
    <p id="p1">Lorem ipsum.</p>
    <p id ="p2">Lorem ipsum dolor sit.</p>
    <a href="#imagess">Başa dön</a>  bak en başta id="imagess" yaptık
                                      çünkü bu kod şu işe yarıyo uzun yazılarda 
                                      aşağı iniyon iniyon başa döne basıyon yukarı çıkıyo
                                      yukarı çıkması için ona id verdik.
    <a href="#p2">p2 ye dön</a> burda 2. paragrafa dön dedik.uzun yazılarda işe yarar.

</body>          2. paragrafa p2 dediğimizi gör.
</html>

# %%
<div></div> arasına koyduğumuz yer bi satırı tamamen kaplar genişletsende küçültsende sekmeyi.
<span< yazıları gruplamak için.özellik eklemek için sonradan.

# %%
https://developer.mozilla.org/tr/docs/HTML/Element

# %%
<iframe> html sayfasına başka html sayfası eklemek.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>idsclasses</title>
    <style>
    
    
        p{ font-size: 20px !important  }
        
        h1{color: brown;}
        
        #header{font-size: 70px} 
        ALTTA H1 E İD OLARAK HEADER VERDİK VE BURADA BÖYLE KULLANDIK
        
        #paragraf{border: 1px solid red} paragraf idsine özellik ekledik #paragraf sayesinde.
        ALTTA P YE İD OLARAK PARAGRAF VERDİK.BAK BU ÖZELLİK#HEADER NOT İÇİN DEĞİL HE ÖZELLİK.
        
        .red{color: red;} .RED YAZDIK REDE ÖZELLİK EKLEDİK AŞAĞIDA CLASS OLARAK ONU YAZINCA
                            COLORA RED DEDİĞİMİZ İÇİN RED OLDU
        .blue{color: blue;}
        
        .f60{font-size: 60px;}  .F60 DİYE BİŞE EKLEDİK CLASSA F60 YAZINCA 60PX YAPSINDEDİK 
        
        .f40{font-size: 40px;}
        
    </style>
</head>
<body>
   <h1 id="header">udemy curslarımıza hoşsel</h1>
   
    <p id="paragraf" style="color: blue">  komple uygula web</p>
    <p class= "blue f60">  komple uygula web</p>
    <p class= "red f40">  komple uygula web</p>
    <p>  komple uygula web</p>
    <p>  komple uygula web</p>
</body>
</html>

# %%
 display: inline yazının olduğu kadar kutucuğa sığar

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>Document</title>
    <link rel="stylesheet" href="style.css">
</head>
<body>
    <div class="container">
    <p class="p1">.container > paragraf1</p>
    <p class="p1">.container > paragraf2</p>
    <div class ="box">.container > box1
    <p>.container > box > paragraf 3 </p>
    <p>.container > box > paragraf 4 </p>
    </div>
    <divc class="box">.container > box 2</div>
    <divc class="box">.container > box 3</div>
    <div>.container > div </div>
    </div>
    <p>paragraf5</p>
     <p> paragraf6</p>
     <div class="box">box4</div>
     <div class="box">box5</div>
     
</body>
</html>


*********DENEMEK İSTERSEN-******************

*{}  yıldız etiketiyle her şeyi seçip özellik ekleyeblirsin.
div p{}  div altında olan p leri seçip özellik ekle.
div,p{}   div ve p yi seçip özellik ekle.
.container div.box{} container altındaki divleri seçiyor, divlerin arasında
                      classı box olanları seçiyor.
div.box{} divlerden sadece classı box olanları seçer.
div>p{} üst elemanı div olan tüm p etiketlerini seçer.
p~div{}divle aynı seviyede olan p etiketlerini seçer.ve p den sonra gelen divleri seçer.
p+div{} p den sonra gelen ilk div etiketini seçer.
p#paragraf paragraf etiketlerinden sadece id si paragraf olanları seçtik.

# %%
<p title="deneme111"></p>
<p title="deneme222"></p>
bu ikisine aynı anda özellik eklemek için:p[title]{}
    
    p[title="deneme222"]{} bu da 2. ye özellik eklemek için.

    a[href~=acilyazilim]{}  burda a içindeki hrefin içindeki yazıda acilyazilim olanları seçtik
     a[href^=https]{} burda a içindeki hrefin içindeki yazıda https ile başlayanları seçtik
    a[href$=com]{} burda a içindeki hrefin içindeki yazıda com ile bitenleri seçtik. com yerine istediğin
                  şey olur yani o kelimeye bağlı.
a[href="www.acilyazilim.com"][_target="blank"] hrefin içinde o siteolacak hemde targeti blank olanları seçtik.
input[type="text"]{} typei text olanları seçtik. inputta,
input[type="button"]{} typei button olanları seçtik. inputta,

# %%
p::first-line{} p etiketlerinin ilk satırını seçtik.
        
<ul>
 <li>ali</li>
 <li>mehmet</li>

</ul>
ul li:first-child{} ul içindeki li nin içindeki aliyi seçtik.
                    first yerine last yazsak son eleman olan ahmeti seçer.

p.about::first-line{} p lerin classında about yazanların ilk satırını seçtik.
p::firs-letter{} p lerin ilk harfini seçtik.
        

p::after{content="-denemeee";
        display=block;}      
        p içindeki yazının sonuna
         "-denemeee" bunu yazdık 
         display= block yapma sebebi "-denemeee" bu yazıyı bi alt satıra almak.
        AFTER YERİNE BEFORE YAPARSAN P NİN BAŞINA GELİR



a:link{
color: red;
}

a:visited{
color:gray;
}

a:hover{     hover üstüne gelince.linkin.
color:white;
background: green;
}

a:active{
color:green;
background: gold;
}
    
a {
padding: 5px 8px;
text-decoration: none;
display: block;
width: 80px;
border:1px solid gray;
margin-bottom: 10px;
}

# %%
table th{
text-align: left;
}
tablodaki başlığı sola çeker.

# %%
h2{
color: 	#FF6347;
}

p{
background-color: rgba(255, 99, 71, 0.4)
}

# %%
<!DOCTYPE html>
<html lang="en">

<head>
<meta charset="UTF-8">
<title>Floating Images</title>
<style>
.clear {           
overflow: auto;             ***İÇERİKTE TAŞMA VARSA ÖNLER.*****
}

p {
border: 1px solid gray;
padding: 5px;
}

img {
width: 200px;
margin-right: 10px;  **resimle yazı arasındaki mesafeyi ayarlar.**
float: left;       *** bu float left resmi sola çekti.***

}
</style>
</head>

<body>


<p>
Lorem ipsum dolor sit amet, consectetur adipisicing elit. Repudiandae nostrum, facere quos expedita ex delectus veritatis in animi, consequatur suscipit atque amet quibusdam ab exercitationem ea pariatur. Id, eum, porro!
</p>

<p class="clear">
<img src="rowing.jpg" alt=""> Lorem ipsum dolor sit amet, consectetur adipisicing elit. Nam, eos. Nobis harum optio iure eaque distinctio, ad consectetur reiciendis magni possimus quo obcaecati quia, facere tempora placeat debitis cupiditate, repudiandae! Lorem ipsum dolor sit amet, consectetur adipisicing elit. Nam, eos. Nobis harum optio iure eaque distinctio, ad consectetur reiciendis magni possimus quo obcaecati quia, facere tempora placeat debitis cupiditate, repudiandae! Lorem ipsum dolor sit amet, consectetur adipisicing elit. Nam, eos. Nobis harum optio iure eaque distinctio, ad consectetur reiciendis magni possimus quo obcaecati quia, facere tempora placeat debitis cupiditate, repudiandae!

</p>

</body>

</html>

# %%
<!DOCTYPE html>
<html lang="en">

<head>
<meta charset="UTF-8">
<title>Css Display</title>
    <style>
/** Display : none | inline | block | inline-block */
  
/** Browser Defaults */

/** Override Defaults */

div{
display: inline-block;
height: 200px;
background: red;
margin: 5px;
}

#first{
width: 500px;
}

span{
background: blue;
width: 200px;
height: 100px;
display: inline-block; ****BUNU YAPMA SEBEBİMİZ NORMALDE SPANIN GENİŞLİĞİNİ VE YÜKSEKLĞİNİ ***
                       ****AYARLAYAMIYORSUN AYARLAYABİLMMEK İÇİN.*****************
}
</style>
</head>

<body>


<div id="first">first</div>
<div id="second">second</div>

<span>deneme 1 Lorem ipsum.</span>  *** SPAN AYNI SATIRA YAZMAYA YARAR.****
<span>deneme 2</span>
<span>deneme 3</span>
<br>
<a href="">Home</a>
<a href="">About</a>
<a href="">Contact</a>

</body>

</html>
DİSPLAY: İNLİNE OLUNCA GENİŞLİK YÜKSEKLİK AYARLAYAMASSIN.

# %%
position:relative
top:50px
left:30px

    
position:sticky

# %%
margin:0    default olan boşlukları siler.
margin:10px 4 kenardanda dıştan 10px boşluk.
margin:10px 4px 3px 8px de yapabilirsin saat yönünde sırayla.
margin-top: 50px
margin-right
margin: auto; sayfanın ortasına koyar.

# %%
padding:20px   4 kenardanda içten 20px boşluk.
    top righ muhabbeti bundada var.

# %%
border: 1px solid red
border-top-width: 1px;
border-right-width: 2px;
border-bottom-width: 3px;
border-left-width: 4px;	
    
border-top-style: solid;
border-right-style: dashed;
border-bottom-style: groove;
border-left-style: double;

border-top-color: red;
border-right-color: aqua;
border-bottom-color: bisque;
border-left-color: blue;
********************************************
border-top: 2px solid blue;
border-top-left-radius: 15px;
border-top-right-radius: 20px;
border-bottom-left-radius: 30px;
border-bottom-right-radius: 40px;
*************************************
border: 3px solid green;
border-radius: 50%;

# %%
<head>
	<meta charset="UTF-8">
	<title>Fonts</title>
	<link href="https://fonts.googleapis.com/css?family=Indie+Flower|Noto+Serif:400,700" rel="stylesheet">
	<style>
	
		body{
			font-family: Arial, Helvetica, sans-serif;
			font-size: 16px;
		}
		
		p{
			font-family: "Comic Sans MS", cursive, sans-serif;
			font-size: 1em;
		}
		
		span{
			font-family: 'Noto Serif', serif;
			font-size: 1em;
		}
		
		div{
			font-family: 'Indie Flower', cursive;
		}
	
	</style>
</head>

<body>

# %%
<head>
	<meta charset="UTF-8">
	<title>Icons</title>
	<link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.0.13/css/all.css" integrity="sha384-DNOHZ68U8hZfKXOrtjWvjxusGo9WQnrNx2sqG0tfsghAvtVlRW3tvkXWZh58N9jp" crossorigin="anonymous">
	
	<style>
		
		
		body{
			font-size: 16px;
		}
	    burda i yi özelleştirdik. aşada
		i{
			color: tomato;
			
		}
		
		.btn{
			padding: 10px;
			border: 1px solid red;
		}
	
	</style>
</head>
<body>


<i class="fab fa-amazon fa-10x"></i> bunu siteden kopyalıyon ikona gelip buraya yapıştır gelir zaten.
<i class="fas fa-ambulance"></i>       fa-10x yapınca 10 katı oldu yukardaki i


	<ul class="fa-ul">
		<li>
			<span class="fa-li">
				<i class="fas fa-check-square"></i>
			</span>
			List
		</li>
		<li>
			<span class="fa-li">
				<i class="fas fa-check-square"></i>
			</span>
			List
		</li>
		<li>
			<span class="fa-li">
				<i class="fas fa-check-square"></i>
			</span>
			List
		</li>
	</ul>


    <div class="fa-3x">
    	
    	<i class="fas fa-spinner fa-spin"></i>
    	
    	<i class="fas fa-spinner fa-pulse"></i>
    </div>


  
  <br>
  <br>
  
   <a href="" class="btn">
   	Button
   </a>
	
</body>

# %%
<head>
	<meta charset="UTF-8">
	<title>Styling Text</title>	
	<link href="https://fonts.googleapis.com/css?family=Open+Sans" rel="stylesheet">
	<style>
	
		body{
			font-family: 'Open Sans', sans-serif;            linki yukarı yapıştırdık. 
                                                            font familyde buraya.
			width: 700px;
			margin: 30px auto;
		}
		
		h2{
			text-transform:capitalize;
		}
		
		p{			
			font-size: 22px;
			line-height: 150%;
			word-spacing: 3px;
			letter-spacing: 1px;
			
		}
		
		.bold{
			font-weight: bold;
		}
		
		.italic{
			font-style: italic;
		}
		
		.link{
			color: #03a9f4;
			text-decoration: none;
		}
	
	</style>	
</head>
<body>

	
	<h2>Lorem ipsum dolor sit amet, consectetur adipisicing.</h2>
	<p>
		Lorem ipsum dolor sit amet, consectetur adipisicing elit. Veritatis, eius, neque. Consequuntur aut eius ex eaque maiores blanditiis alias aperiam modi architecto, itaque quidem? Odit dolores cum, illo culpa 
		<span class="bold italic">
			<a class="link" href="#">recusandae.</a>
		</span>
	</p>
	
	
	
</body>

# %%
<head>
	<meta charset="UTF-8">
	<title>Aligning Text</title>
	<link href="https://fonts.googleapis.com/css?family=Open+Sans" rel="stylesheet">
	<style>
		
		body {
			font-family: 'Open Sans', sans-serif;
			width: 900px;
			margin: 30px auto;
		}		
		
		p#first{
			text-align: right;      texti sağa kaydırdı
		}
		
		p#second{
			text-align: center;      text ortaya kaydı
		}
		
		p#third{ 
			text-align: left;                         text sola kaydı.
			border: 1px solid rgb(0,0,0,0.4);
			padding: 10px;
			
			column-count: 3;
			-webkit-column-count: 3; /*opera chrome safari */
			-moz-column-count: 3;   /*mozilla*/
			
			column-rule: 1px solid rgb(0,0,0,0.4);
			-webkit-column-rule: 1px solid rgb(0,0,0,0.4);
			-moz-column-rule: 1px solid rgb(0,0,0,0.4);
			
		}
		
		p#forth{
		  text-align: justify;     sol ve sağ hizalı yapar.
			text-indent: 10px;
		}
		
		div{
			text-align: right;
		}
		
	</style>
</head>

<body>


	<h2>Lorem ipsum dolor sit amet, consectetur adipisicing.</h2>
	<p id="first">
		Lorem ipsum dolor sit amet, consectetur adipisicing elit. Veritatis, eius, neque. Consequuntur aut eius ex eaque maiores blanditiis alias aperiam modi architecto, itaque quidem? 
		Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eaque voluptatum maiores culpa, placeat harum inventore illo dolorem in, ipsam earum facere error sunt quidem aperiam enim provident eveniet nesciunt pariatur!
	</p>
	
	<p id="second">
		Lorem ipsum dolor sit amet, consectetur adipisicing elit. Veritatis, eius, neque. Consequuntur aut eius ex eaque maiores blanditiis alias aperiam modi architecto, itaque quidem? 
		Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eaque voluptatum maiores culpa, placeat harum inventore illo dolorem in, ipsam earum facere error sunt quidem aperiam enim provident eveniet nesciunt pariatur!
	</p>
	
	<p id="third">
		Lorem ipsum dolor sit amet, consectetur adipisicing elit. Veritatis, eius, neque. Consequuntur aut eius ex eaque maiores blanditiis alias aperiam modi architecto, itaque quidem? 
		Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eaque voluptatum maiores culpa, placeat harum inventore illo dolorem in, ipsam earum facere error sunt quidem aperiam enim provident eveniet nesciunt pariatur!
	</p>
	
	
	<p id="forth">
		Lorem ipsum dolor sit amet, consectetur adipisicing elit. Veritatis, eius, neque. Consequuntur aut eius ex eaque maiores blanditiis alias aperiam modi architecto, itaque quidem? 
		Lorem ipsum dolor sit amet, consectetur adipisicing elit. Eaque voluptatum maiores culpa, placeat harum inventore illo dolorem in, ipsam earum facere error sunt quidem aperiam enim provident eveniet nesciunt pariatur!
	</p>
	
	
	<div>
	
	<a href="">Link 1</a>
	<a href="">Link 2</a>
	<a href="">Link 3</a>
</div>

</body>

# %%
	<div id="share" class="box">
				
				<a href="#">
					<i class="fab fa-facebook fa-2x"></i>
				</a>
				<a href="#">
					<i class="fab fa-twitter-square fa-2x"></i> 
				</a>
				<a href="#">
					<i class="fab fa-youtube-square fa-2x"></i>
				</a>
				<a href="#">
					<i class="fab fa-instagram fa-2x"></i>
				</a>
				
				
			</div>        face youtube iconu ekledik ve tıklanabilir yaptık.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
	<meta charset="UTF-8">
	<title>Box Shadow</title>
	
	<style>
		
		body{
			background: #f2f2f2;
		}
	
		.card{
			width: 200px;
			height: 200px;
			background: #fff;
			border-radius: 2px;
			margin: 20px;
			display: inline-block;
		}
		
		.card-1{
			-webkit-box-shadow: 10px 10px;
			-mox-box-shadow: 10px 10px;
			box-shadow: 10px 10px;
		}
		
		.card-2{
			-webkit-box-shadow:  10px 10px 20px;
			-mox-box-shadow:  10px 10px 20px;
			box-shadow: 10px 10px 20px;
		}
		
		.card-3{
			-webkit-box-shadow:10px 10px 20px 2px rgba(0,0,0,.3);
			-mox-box-shadow: 10px 10px 20px 2px rgba(0,0,0,.3);
			box-shadow: 10px 10px 20px 2px rgba(0,0,0,.3);
		}
		
		.card-4{
			
		}
		
		.card-4:hover{
			-webkit-box-shadow:10px 10px 20px 2px rgba(0,0,0,.3);
			-mox-box-shadow: 10px 10px 20px 2px rgba(0,0,0,.3);
			box-shadow: 10px 10px 20px 2px rgba(0,0,0,.3);
		}
		
		.card-5{		
			box-shadow: 0 3px 6px rgba(0,0,0,0.16),0 3px 6px rgba(0,0,0,0.30);
		}
		
		.card-6{
			border: 1px solid #BFBFBF;
			box-shadow: 10px 10px 5px #aaaaaa;
		}
	
	
	</style>
</head>
<body>
	
	<div class="card card-1"></div>
	<div class="card card-2"></div>
	<div class="card card-3"></div>
	<div class="card card-4"></div>
	<div class="card card-5"></div>
	<div class="card card-6"></div>
	
	
</body>
</html>

# %%
<head>
	<meta charset="UTF-8">
	<title>Box Shadow</title>

	<style>
		.card {
			width: 150px;
			height: 150px;
			background: blue;
			-webkit-transition: width 2s, height 2s, background 1s;******geçiş efekt muhabbeti*****
			transition: width 2s, height 2s, background 1s;
			transition-delay: 1s;
			margin-bottom: 10px;
		}

		.card:hover {
			width: 250px;				
		}
		
		#card1{
			transition-timing-function: ease;
		}
		#card2{
			transition-timing-function: linear;
		}
		#card3{
			transition-timing-function: ease-in;
		}
		#card4{
			transition-timing-function: ease-out;
		}
		#card5{
			transition-timing-function: ease-in-out;
		}

	</style>
</head>

# %%
class için   .xxxxxx
id için      #xxxxxx diye özellik eklemen lazım.

# %%
<!DOCTYPE html>
<html lang="en">

<head>
	<meta charset="UTF-8">
	<title>Yatay Menu</title>
	<style>
		ul {
			list-style: none;
			margin: 0;
			padding: 0;
			position: absolute;
		}

		li {
			display: inline-block;
			float: left;
			margin-right: 1px;
		}


		li a {
			display: block;
			background: #2f3036;
			min-width: 140px;
			color: #fff;
			text-decoration: none;
			height: 50px;
			line-height: 50px;
			text-align: center;
			font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
		}

		li a:hover {
			background: #19C589;
		}

		li:hover ul a {
			background: #f3f3f3;
			color: black;
			height: 40px;
			line-height: 40px;
		}

		li:hover ul a:hover {
			background: #19C589;
			color: #fff;
		}

		li ul li {
			display: block;
			float: none;
		}

		li ul li a {
			text-align: left;
			min-width: 100px;
			padding: 0 20px;
		}

		li:hover a {
			background: #19C589;
		}

		li ul {
			display: none;
		}

		ul li a:hover+.hidden,
		.hidden:hover {
			display: block;
		}

		ul li:hover ul {
			display: block;
		}

	</style>
</head>

<body>

	<ul>
		<li>
			<a href="#">Anasayfa</a>
		</li>
		<li>
			<a href="#">Hakkımızda</a>
		</li>
		<li>
			<a href="#">Kurslar</a>
			<ul class="hidden">
				<li><a href="#">Komple Uygulamalı Web Geliştirme Eğitimi</a></li>
				<li><a href="#">Web Programlama Eğitimi : Asp.net MVC</a></li>
				<li><a href="#">C# Programlama Dili Eğitimi</a></li>
			</ul>

		</li>
		<li>
			<a href="#">Makale</a>
		</li>
		<li>
			<a href="#">İletişim</a>
		</li>


	</ul>



</body>

</html>

*********YATAY AÇILAN MENU***************

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>Responsive Web</title>
    <meta name="viewport" content="width=device-width">  
      
    <style>   
       
        *{
            box-sizing: border-box;
        }
        
        .box{
            width: 25%;
            height: 250px;
            background: yellow;
            float: left;
            border: 1px solid blue;
        }
        
        
        @media screen and (max-width:700px)     700px aşağısına geldimi kutu yüzde 50 kaplasın
        {
            .box{
                width: 50%;              
            }
        }
        
        @media screen and (max-width:400px)            400px aşağısına geldimi kutu yüxde yüz kaplasın
        {
            .box{
                width: 100%;              
            }
        }
        
        
    </style>
    
</head>
<body>
   
     
       <div class="box"></div>
       <div class="box"></div>
       <div class="box"></div>
       <div class="box"></div>
       <div class="box"></div>
       
    
</body>
</html>

# %%
display: flex;  inline block yapar
			// flex-direction: row-reverse;  sağa hizalar
			// flex-direction: column; alt alta sıralar ve satırı tamamen kaplar
			// flex-direction: column-reverse; hizalama 1234 yerine 4321 şeklinde olur alt alta
			// flex-wrap: nowrap; varsayılan
			// flex-wrap: wrap; sığmmayanları aşağı inmesini sağlar.
			flex-wrap: wrap-reverse;
			background-color: #f2f2f2;
			padding: 15px;

# %%
.container {
			
			height: 1200px;
			
			display: flex;
			flex-direction: column;
			justify-content: space-around;
			// justify-content: flex-start; elemanlar sola hizalanır.
			// justify-content: flex-end;   elemanlar sağa hizalanır
			// justify-content: space-between; aralarda boşluk bırakılır
			// justify-content: space-around;  x 2x 2x x şeklinde boşluk bırakılır.
			// justify-content: space-evenly; her yerden eşit boşluk bırakılır.
			
			// align-items: stretch;
			// align-items: center; elemanlar ortaya sıralaın
			// align-items: flex-start; elemanlar üste sıralanır
			 align-items: flex-end; elemanlar alta sıralarnır
			// align-items: baseline; içeriğin tam altından sırlaama yapar.
			
			
			background-color: #f2f2f2;
			padding: 15px;
		}

# %%
.i4 {
			
			order: -1;
		}   sırayla   esim veya objeler var diyelim i1 i2 i3 i4 diye bu özellikle i4 ü başa alabilirsin 
            i3 e -2 desek o en başa gelir.-2 daha küçük olduğu için

# %%
flex %25 falan yazarak genişlikte iki farklı yerin kapladığı yeri ayarlar.
